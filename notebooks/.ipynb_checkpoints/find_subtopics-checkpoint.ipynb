# %%
import json
import networkx as nx
import numpy as np
import gensim
from sklearn.decomposition import TruncatedSVD, NMF
from pymongo.mongo_client import MongoClient
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
model = gensim.models.Doc2Vec.load('../models/doc2vec_22k')
vecs = model.docvecs

# %%
print("There are %d document vectors"%len(model.docvecs))
# Out:
# There are 22000 document vectors

# %%
collection = MongoClient().arxiv.articles
ai_docs = collection.find({'arxiv_primary_category.term': 'cs.AI'})
ai_vecs = np.array([vecs[doc['id']] for doc in ai_docs])

# %%
# # add similars to the database for future ref
# for item in collection.find():
#     similars = model.docvecs.most_similar(positive=[item['id']])
#     collection.update_one({'id': item['id']}, {'$set': {'similars': similars}})

# %%
# don't know why this isn't working... gonna do it all in a function
#collection.aggregate([{'$group': 'arxiv_primary_category.term', 'count': { '$sum': 1 } }])

# %%
ai_vecs.shape # num of docs by num of features
# Out:
# (165, 300)

# %%
# topic_finder = NMF(n_components=3, init='random', random_state=0) # NMF doesn't work because docvecs include negative numbers

# %%
topic_finder = TruncatedSVD(n_components=3, algorithm='randomized', random_state=0)

# %%
topic_finder.fit_transform(ai_vecs)
# Out:
# (165, 3)

# %%
"""
topic_finder may have gotten rid of some false positives,
but i want to establish a baseline first using simple cosine similarity
to establish a network of papers clustered by their similarity 
"""
# Out:
# '\ntopic_finder may have gotten rid of some false positives,\nbut i want to establish a baseline first using simple cosine similarity\nto establish a network of papers clustered by their similarity \n'

# %%
model.docvecs.most_similar(positive=['http://arxiv.org/abs/1210.4984v1'])
# Out:
# [('http://arxiv.org/abs/1408.0799v1', 0.39159345626831055),
#  ('http://arxiv.org/abs/1307.6593v1', 0.3561500310897827),
#  ('http://arxiv.org/abs/1410.6021v1', 0.34113651514053345),
#  ('http://arxiv.org/abs/1307.7213v1', 0.339904248714447),
#  ('http://arxiv.org/abs/1407.6238v1', 0.33090412616729736),
#  ('http://arxiv.org/abs/1407.6006v1', 0.3290548026561737),
#  ('http://arxiv.org/abs/1412.6445v1', 0.32500267028808594),
#  ('http://arxiv.org/abs/1405.0706v2', 0.31701111793518066),
#  ('http://arxiv.org/abs/1404.6077v1', 0.3153367042541504),
#  ('http://arxiv.org/abs/1404.3247v2', 0.3109501004219055)]

# %%
model.docvecs.most_similar(positive=['http://arxiv.org/abs/1408.0799v1'])
# Out:
# [('http://arxiv.org/abs/1412.5884v1', 0.6321225762367249),
#  ('http://arxiv.org/abs/1502.07355v2', 0.6081972122192383),
#  ('http://arxiv.org/abs/1508.03669v1', 0.5583994388580322),
#  ('http://arxiv.org/abs/1503.06135v1', 0.5558384656906128),
#  ('http://arxiv.org/abs/1502.07675v1', 0.5535378456115723),
#  ('http://arxiv.org/abs/1502.04171v1', 0.5530827045440674),
#  ('http://arxiv.org/abs/1408.2511v1', 0.5529962778091431),
#  ('http://arxiv.org/abs/1410.0497v1', 0.5518239736557007),
#  ('http://arxiv.org/abs/1411.3628v2', 0.5495747327804565),
#  ('http://arxiv.org/abs/1410.0367v1', 0.5455210208892822)]

# %%
print((collection.find_one()['similars']))
# Out:
# [['http://arxiv.org/abs/1306.0749v1', 0.21769024431705475], ['http://arxiv.org/abs/1305.6256v1', 0.2108001708984375], ['http://arxiv.org/abs/1304.4428v2', 0.20757810771465302], ['http://arxiv.org/abs/1410.1160v1', 0.2063044011592865], ['http://arxiv.org/abs/1305.6262v1', 0.2054666429758072], ['http://arxiv.org/abs/1306.0543v2', 0.20441943407058716], ['http://arxiv.org/abs/1308.3207v2', 0.1975361555814743], ['http://arxiv.org/abs/1307.4125v1', 0.19572174549102783], ['http://arxiv.org/abs/1401.4383v1', 0.19484572112560272], ['http://arxiv.org/abs/1307.8378v2', 0.19468888640403748]]

# %%
g = nx.Graph()

# %%
for ai_doc in collection.find({'arxiv_primary_category.term': 'cs.AI'}):
    for sim in ai_doc['similars']:
        g.add_edge(ai_doc['id'], sim[0], weight=sim[1])

# %%
elarge=[(u,v) for (u,v,d) in g.edges(data=True) if d['weight'] >0.5]
esmall=[(u,v) for (u,v,d) in g.edges(data=True) if d['weight'] <=0.5]

# %%
pos=nx.spring_layout(g)

# %%
fig = plt.figure(figsize=(12,12))
# edges
nx.draw_networkx_edges(g,pos,edgelist=elarge,width=0.5)
nx.draw_networkx_edges(g,pos,edgelist=esmall,width=0.1,alpha=0.5,edge_color='b',style='dashed')

# labels
# nx.draw_networkx_labels(g,pos,font_size=20,font_family='sans-serif')

plt.axis('off')
# plt.savefig("weighted_graph.png") # save as png
plt.show() # display
# Out:
# /Applications/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# /Applications/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
